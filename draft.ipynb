# %%
import numpy as np
import load_mnist
training_data, test_data = load_mnist.load_data()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 import numpy as np
#       2 import load_mnist
# ----> 3 training_data, test_data = load_mnist.load_data()
#
# File ~\Documents\AI\load_mnist.py:16, in load_data()
#      15 def load_data():
# ---> 16     with gzip.open('mnist.pkl.gz', 'rb') as f:
#      17         train_data, validation_data, test_data = pickle.load(f, encoding='latin1')
#      18     return (shape_data(train_data), shape_data(test_data))
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.1520.0_x64__qbz5n2kfra8p0\Lib\gzip.py:58, in open(filename, mode, compresslevel, encoding, errors, newline)
#      56 gz_mode = mode.replace("t", "")
#      57 if isinstance(filename, (str, bytes, os.PathLike)):
# ---> 58     binary_file = GzipFile(filename, gz_mode, compresslevel)
# ...

# %%
type(training_data), len(training_data), type(test_data), len(test_data)
# Out:
# (list, 50000, list, 10000)

# %%
data = training_data[0]
type(data), len(data), type(data[0]), data[0].shape, type(data[1]), data[1].shape
# Out:
# (tuple, 2, numpy.ndarray, (784, 1), numpy.ndarray, (10, 1))

# %%
img = np.array(data[0]).reshape(28,28)
img.shape
# Out:
# (28, 28)

# %%
import matplotlib.pyplot as plt
fig, axes = plt.subplots(15,8, figsize=(28,28))
for i,ax in enumerate(axes.flat):
    img = np.array(training_data[i][0]).reshape(28,28)
    ax.imshow(img)
